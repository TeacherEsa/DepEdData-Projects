# %% [markdown]
# #### Dataset: DepEd 10% Schools (Stratified) 2015 NAT takers
#
# - Classification goal: To predict NAT Overall Score
# - Number of Instances: 3377 for depedES.csv
# - Number of Attributes: 20 + output attribute.

# %% [markdown]
# ### Attributes (DepEd ES data)
#    1. SchID: unique 6-digit code assigned to public school (numeric)
#    2. SchName : name of school (object: text)
#    3. DivName : division name (object: mixed characters)
#    4. DivCode : division code (object: mixed characters)
#    5. Clusters: NAT grouping by DepEd (categorical: "1", "2", "3", "4", "5", "6")
#    6. Region: schools regional location (categorical: values 1 to 16)
#    7. Filipino: school average filipino NAT score (numerical 0 to 100)
#    8. AralinP: school average araling panlipunan NAT score (numerical 0 to 100)
#    9. Mathematics: school average mathematics NAT score (numerical 0 to 100)
#    10. Science: school average science NAT score  (numerical 0 to 100)
#    11. English: school average english NAT score (numerical 0 to 100)
#    12. Overall: school average NAT score (numerical 0 to 100)
#    13. Internet: does school have internet (binary: 0 means "no", 1 means "yes")
#    14. Lat: latitude coordinate location of school (numeric: -90 to 90)
#    15. Long: longitude coordinate location of school (numeric: -180 to 180)
#    16. Enrolled: number of students  (numeric)
#    17. Teacher: number of teacher items (numeric)
#    18. Ratio: teacher to student ratio(numeric between 0 to 1)
#    19. Energized : does school have electricity (binary: 0 means "no", 1 means "yes")
#    20. SchType: type of school (categorical: "School with no annexes","mother school", "Annex or extension")

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# ### Standard Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# %matplotlib inline

# %%
# Set Options for display
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
pd.options.display.float_format = '{:.2f}'.format

#Filter Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Additional Libraries

# %%
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# ## Load the Dataset
# * Specify the Parameters (Filepath, Index Column)
# * Check for Date-Time Columns to Parse Dates
# * Check Encoding if file does not load correctly

# %%
DF = pd.read_csv('DepEd_ES.csv')

# %% [markdown]
# ________

# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Describe the Data

# %%
# Check if the Data loaded correctly
DF.head()
# Out:
#     SchID          SchName DivName DivisionCode Province MunicipalityORCity  \
# 0  134968  Bangued East CS    Abra          N01     ABRA  BANGUED (Capital)
# 1  135008       Siwasiw ES    Abra          N01     ABRA              BUCAY
# 2  134995       Layugan ES    Abra          N01     ABRA              BUCAY
# 3  135182      Ducligan ES    Abra          N01     ABRA             BUCLOC
# 4  135022         Pacac ES    Abra          N01     ABRA            DOLORES
#
#    Clusters Region  Filipino  AralinP  Mathematics  Science  English  Overall  \
# 0         4    CAR     44.01    37.46        52.29    36.13    41.76    42.33
# 1         5    CAR     64.40    64.73        63.26    69.84    65.05    65.46
# 2         5    CAR     67.80    75.98        68.78    81.34    86.22    76.02
# 3         6    CAR     72.88    73.85        69.81    58.85    76.35    70.35
# 4         6    CAR     72.71    80.42        83.33    78.75    78.54    78.75
#
#    Internet   Lat   Long  Enrolled  Teachers  Ratio  Energized  Grid  \
# 0         0 17.60 120.62       443        19     23          1     1
# 1         1 17.54 120.74       225         6     37          1     1
# 2         0 17.50 120.71       295         9     32          1     1
# 3         0 17.44 120.80       248        12     20          1     1
# 4         1 17.66 120.72        76         4     19          1     1
#
#                SchoolType     PBOR  PovertyCluster  PovertyIncidence  \
# 0  School with no Annexes 15781.00               3                20
# 1  School with no Annexes 15781.00               3                20
# 2  School with no Annexes 15781.00               3                20
# 3  School with no Annexes 15781.00               3                20
# 4  School with no Annexes 15781.00               3                20
#
#    LowerLimit  UpperLimit
# 0          16          53
# 1          16          53
# 2          16          53
# 3          16          53
# 4          16          53

# %%
# Check the dimensions
DF.shape
# Out:
# (3377, 28)

# %%
#Check the features
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3377 entries, 0 to 3376
# Data columns (total 28 columns):
# SchID                 3377 non-null int64
# SchName               3377 non-null object
# DivName               3377 non-null object
# DivisionCode          3377 non-null object
# Province              3377 non-null object
# MunicipalityORCity    3377 non-null object
# Clusters              3377 non-null int64
# Region                3377 non-null object
# Filipino              3377 non-null float64
# AralinP               3377 non-null float64
# Mathematics           3377 non-null float64
# Science               3377 non-null float64
# English               3377 non-null float64
# Overall               3377 non-null float64
# Internet              3377 non-null int64
# Lat                   3377 non-null float64
# Long                  3377 non-null float64
# Enrolled              3377 non-null int64
# Teachers              3377 non-null int64
# Ratio                 3377 non-null int64
# Energized             3377 non-null int64
# Grid                  3377 non-null int64
# SchoolType            3377 non-null object
# PBOR                  3377 non-null float64
# PovertyCluster        3377 non-null int64
# PovertyIncidence      3377 non-null int64
# LowerLimit            3377 non-null int64
# UpperLimit            3377 non-null int64
# dtypes: float64(9), int64(12), object(7)
# memory usage: 738.8+ KB

# %%
#Check for Column Names
DF.columns
# Out:
# Index([u'SchID', u'SchName', u'DivName', u'DivisionCode', u'Province',
#        u'MunicipalityORCity', u'Clusters', u'Region', u'Filipino', u'AralinP',
#        u'Mathematics', u'Science', u'English', u'Overall', u'Internet', u'Lat',
#        u'Long', u'Enrolled', u'Teachers', u'Ratio', u'Energized', u'Grid',
#        u'SchoolType', u'PBOR', u'PovertyCluster', u'PovertyIncidence',
#        u'LowerLimit', u'UpperLimit'],
#       dtype='object')

# %%
#Get the Stats on the Data
DF.describe(include='all')
# Out:
#            SchID        SchName DivName DivisionCode Province  \
# count    3377.00           3377    3377         3377     3377
# unique       nan           2990     210          212       86
# top          nan  San Isidro ES   Leyte          H04    LEYTE
# freq         nan             23     105          105      119
# mean   121042.84            NaN     NaN          NaN      NaN
# std     20254.52            NaN     NaN          NaN      NaN
# min    100003.00            NaN     NaN          NaN      NaN
# 25%    109134.00            NaN     NaN          NaN      NaN
# 50%    118739.00            NaN     NaN          NaN      NaN
# 75%    127712.00            NaN     NaN          NaN      NaN
# max    500019.00            NaN     NaN          NaN      NaN
#
#        MunicipalityORCity  Clusters Region  Filipino  AralinP  Mathematics  \
# count                3377   3377.00   3377   3377.00  3377.00      3377.00
# unique               1160       nan     17       nan      nan          nan
# top            DAVAO CITY       nan   VIII       nan      nan          nan
# freq                   34       nan    347       nan      nan          nan
# mean                  NaN      4.89    NaN     71.92    74.10        76.91
# std                   NaN      1.08    NaN     11.82    16.10        17.70
# min                   NaN      1.00    NaN     27.00    16.84        16.61
# 25%                   NaN      4.00    NaN     64.37    65.00        67.32
# 50%                   NaN      5.00    NaN     73.28    77.71        81.60
# 75%                   NaN      6.00    NaN     81.06    86.39        90.49
# max                   NaN      6.00    NaN     97.50    99.83       100.00
#
#         Science  English  Overall  Internet     Lat    Long  Enrolled  \
# count   3377.00  3377.00  3377.00   3377.00 3377.00 3377.00   3377.00
# unique      nan      nan      nan       nan     nan     nan       nan
# top         nan      nan      nan       nan     nan     nan       nan
# freq        nan      nan      nan       nan     nan     nan       nan
# mean      71.67    76.67    74.25      0.41   11.92  122.87    508.84
# std       16.77    15.32    14.01      0.49    3.46    1.83   1308.85
# min       21.29    24.00    26.00      0.00    4.79  117.09     11.00
# 25%       61.02    68.89    66.38      0.00    8.95  121.15    154.00
# 50%       74.62    80.38    77.36      0.00   11.68  122.98    255.00
# 75%       84.84    88.12    84.95      1.00   14.66  124.47    489.00
# max      100.00   100.00    97.50      1.00   60.70  126.57  58709.00
#
#         Teachers   Ratio  Energized    Grid              SchoolType     PBOR  \
# count    3377.00 3377.00    3377.00 3377.00                    3377  3377.00
# unique       nan     nan        nan     nan                       4      nan
# top          nan     nan        nan     nan  School with no Annexes      nan
# freq         nan     nan        nan     nan                    3310      nan
# mean       14.55   31.98       0.91    0.86                     NaN  5889.64
# std        35.39   10.28       0.28    0.34                     NaN  5666.44
# min         1.00    2.00       0.00    0.00                     NaN   277.29
# 25%         6.00   25.00       1.00    1.00                     NaN   277.29
# 50%         8.00   32.00       1.00    1.00                     NaN  8982.00
# 75%        14.00   38.00       1.00    1.00                     NaN 10732.00
# max      1630.00  177.00       1.00    1.00                     NaN 15781.00
#
#         PovertyCluster  PovertyIncidence  LowerLimit  UpperLimit
# count          3377.00           3377.00     3377.00     3377.00
# unique             nan               nan         nan         nan
# top                nan               nan         nan         nan
# freq               nan               nan         nan         nan
# mean              3.03             21.68       15.55       27.10
# std               1.24             12.92       10.65       16.04
# min               1.00              0.00        0.00        0.00
# 25%               2.00             12.00        8.00       16.00
# 50%               3.00             19.00       14.00       25.00
# 75%               4.00             30.00       21.00       39.00
# max               5.00             66.00       61.00       72.00

# %% [markdown]
# ## Verify Data Quality

# %% [markdown]
# Look out for the following:
# * Incorrect or unexpected data type & format (ALL)
# * Duplicates (ALL)
# * Unexpected dimensions (i.e. missing rows or columns) (ALL)
# * Incorrect Spelling (CAT)
# * Mixed cases for strings (CAT)
# * Unexpected outliers or anomalous values (NUM)
# * Inconsistent or incorrect units of measurement (NUM)

# %% [markdown]
# ### All

# %%
#Incorrect or unexpected data type & format (ALL)
DF.dtypes
# Out:
# SchID                   int64
# SchName                object
# DivName                object
# DivisionCode           object
# Province               object
# MunicipalityORCity     object
# Clusters                int64
# Region                 object
# Filipino              float64
# AralinP               float64
# Mathematics           float64
# Science               float64
# English               float64
# Overall               float64
# Internet                int64
# Lat                   float64
# Long                  float64
# Enrolled                int64
# Teachers                int64
# Ratio                   int64
# Energized               int64
# Grid                    int64
# SchoolType             object
# PBOR                  float64
# PovertyCluster          int64
# PovertyIncidence        int64
# LowerLimit              int64
# UpperLimit              int64
# dtype: object

# %%
#Duplicates (ALL). 

# Checks for Duplicated Samples
DF.duplicated().value_counts()
# Out:
# False    3377
# dtype: int64

# %% [markdown]
# **Check Columns for Missing Values**

# %%
DF.isnull().sum()
#df.info works also
# Out:
# SchID                 0
# SchName               0
# DivName               0
# DivisionCode          0
# Province              0
# MunicipalityORCity    0
# Clusters              0
# Region                0
# Filipino              0
# AralinP               0
# Mathematics           0
# Science               0
# English               0
# Overall               0
# Internet              0
# Lat                   0
# Long                  0
# Enrolled              0
# Teachers              0
# Ratio                 0
# Energized             0
# Grid                  0
# SchoolType            0
# PBOR                  0
# PovertyCluster        0
# PovertyIncidence      0
# LowerLimit            0
# UpperLimit            0
# dtype: int64

# %% [markdown]
# #### Split the Dataset into Categorical and Numerical Features

# %%
#Categorical Features Only
DF_cat = DF.select_dtypes(include=['object'])

#Numerical Features Only
DF_num = DF.select_dtypes(include=['int64','float64'])

# %% [markdown]
# ### Categorical Data

# %%
#Incorrect Spelling (CAT)
#Mixed cases for strings (CAT)

# %%
#Check the Number of Categorical Features
DF_cat.shape
# Out:
# (3377, 7)

# %%
#Describe the Categorical Features. Check if Number of Unique Values is as expected. 
DF_cat.describe(include='object')
# Out:
#               SchName DivName DivisionCode Province MunicipalityORCity Region  \
# count            3377    3377         3377     3377               3377   3377
# unique           2990     210          212       86               1160     17
# top     San Isidro ES   Leyte          H04    LEYTE         DAVAO CITY   VIII
# freq               23     105          105      119                 34    347
#
#                     SchoolType
# count                     3377
# unique                       4
# top     School with no Annexes
# freq                      3310

# %%
#Other Methods to Check: Value Counts
DF_cat.Region.value_counts()
# Out:
# VIII      347
# IV-A      290
# V         287
# III       286
# VI        267
# VII       258
# I         217
# X         201
# IX        189
# II        183
# IV-B      166
# XI        154
# CARAGA    143
# XII       126
# CAR       123
# ARMM       98
# NCR        42
# Name: Region, dtype: int64

# %%
#Other Methods to Check: Unique
DF_cat.DivName.unique()
# Out:
# array(['Abra', 'Agusan Del Norte', 'Butuan City', 'Cabadbaran City',
#        'Agusan Del Sur', 'Bayugan City', 'Aklan', 'Albay', 'Ligao City',
#        'Tabaco City', 'Legaspi City', 'Antique', 'Apayao', 'Aurora',
#        'Lamitan', 'Basilan', 'Balanga City', 'Bataan', 'Batanes',
#        'Batangas', 'Batangas City', 'Tanauan City', 'Lipa City',
#        'Benguet', 'Baguio City', 'Biliran', 'Bohol', 'Tagbilaran City',
#        'Bukidnon', 'Malaybalay City', 'Valencia City', 'Bulacan',
#        'Malolos City', 'Meycauayan City', 'San Jose Del Monte City',
#        'Cagayan', 'Tuguegarao City', 'Camarines Norte', 'Camarines Sur',
#        'Iriga City', 'Naga City', 'Camiguin', 'Capiz', 'Roxas City',
#        'Catanduanes', 'Cavite', 'Bacoor', 'Cavite City',
#        'Dasmari\xc3\xb1as', 'Imus', 'Cebu', 'Cebu City', 'Bogo City',
#        'Carcar City', 'Naga City - R7', 'Talisay City', 'Danao City',
#        'Lapu-Lapu City', 'Mandaue City', 'Toledo City', 'Cotabato City',
#        'Isabela City', 'Compostela Valley', 'Davao Del Norte',
#        'Panabo City', 'Tagum City', 'Island Garden City Of Samal',
#        'Davao Del Sur', 'Digos City', 'Davao City', 'Davao Oriental',
#        'Mati City', 'Dinagat Island', 'Eastern Samar', 'Borongan City',
#        'Guimaras', 'Ifugao', 'Ilocos Norte', 'Batac City', 'Laoag City',
#        'Ilocos Sur', 'Candon City', 'Vigan City', 'Iloilo', 'Passi City',
#        'Iloilo City', 'Isabela', 'Cauayan City', 'Santiago City',
#        'Ilagan City', 'Kalinga', 'Tabuk City', 'La Union',
#        'San Fernando City', 'Laguna', 'Calamba City', 'San Pablo City',
#        'Lanao Del Norte', 'Iligan City', 'Lanao Del Sur II',
#        'Lanao Del Sur I', 'Marawi City', 'Leyte', 'Baybay City',
#        'Ormoc City', 'Tacloban City', 'Maguindanao I', 'Maguindanao II',
#        'Marinduque', 'Masbate', 'Masbate City', 'Misamis Occidental',
#        'Oroquieta City', 'Ozamis City', 'Tangub City', 'Misamis Oriental',
#        'Cagayan De Oro City', 'El Salvador City', 'Gingoog City',
#        'Mt. Province', 'Las Pi\xc3\xb1as City', 'Makati City',
#        'Malabon City', 'Marikina City', 'Muntinlupa City', 'Navotas City',
#        'Paranaque City', 'Pasig City', 'San Juan City', 'Valenzuela City',
#        'Caloocan City', 'Manila', 'Taguig / Pateros', 'Quezon City',
#        'Bacolod City', 'Bago City', 'Negros Occidental', 'Cadiz City',
#        'Escalante City', 'Kabankalan City', 'La Carlota City',
#        'Sagay City', 'San Carlos City', 'Silay City', 'Negros Oriental',
#        'Bais City', 'Bayawan City', 'Guihulngan', 'Tanjay City',
#        'Dumaguete City', 'North Cotabato', 'Kidapawan City',
#        'Northern Samar', 'Nueva Ecija', 'Cabanatuan City', 'Gapan City',
#        'San Jose City', 'Munoz Science City', 'Nueva Vizcaya',
#        'Occidental Mindoro', 'Oriental Mindoro', 'Calapan City',
#        'Palawan', 'Puerto Princesa City', 'Angeles City', 'Pampanga',
#        'Mabalacat City', 'Pangasinan I (Lingayen)',
#        'Pangasinan II (Binalonan)', 'Alaminos City', 'Urdaneta City',
#        'Dagupan City', 'Quezon', 'Tayabas City', 'Lucena City', 'Quirino',
#        'Rizal', 'Antipolo City', 'Romblon', 'Sarangani', 'Siquijor',
#        'Sorsogon', 'Sorsogon City', 'South Cotabato', 'Koronadal City',
#        'General Santos City', 'Southern Leyte', 'Maasin City',
#        'Sultan Kudarat', 'Tacurong City', 'Sulu', 'Surigao Del Norte',
#        'Siargao', 'Surigao City', 'Surigao Del Sur', 'Bislig City',
#        'Tarlac', 'Tarlac City', 'Tawi-Tawi', 'Samar (Western)',
#        'Calbayog City', 'Catbalogan City', 'Zambales',
#        'Zamboanga Del Norte', 'Dapitan City', 'Dipolog City',
#        'Zamboanga Del Sur', 'Pagadian City', 'Zamboanga City',
#        'Zamboanga Sibugay'], dtype=object)

# %%
#for loop to go over all the features and print out the unique values for each feature. 
for cat_col in DF_cat.columns:
    print (DF[cat_col].value_counts())
    print ("\n---------")
# Out:
# San Isidro ES                              23
# San Jose ES                                15
# San Vicente ES                             15
# San Antonio ES                             15
# San Juan ES                                13
# Salvacion ES                               10
# Mabini ES                                   9
# San Francisco ES                            7
# Magsaysay ES                                7
# Buenavista ES                               7
# Rizal ES                                    7
# Bagacay ES                                  7
# San Roque ES                                7
# Imelda ES                                   6
# Concepcion ES                               6
# San Pablo ES                                6
# Sto. Rosario ES                             6
# Mabuhay ES                                  6
# San Agustin ES                              6
# Esperanza ES                                5
# Sta. Cruz ES                                5
# San Miguel ES                               5
# Katipunan ES                                5
# Alegria ES                                  5
# San Pedro ES                                5
# Looc ES                                     5
# San Pascual ES                              5
# San Rafael ES                               5
# Libertad ES                                 5
# Talisay ES                                  4
# Union ES                                    4
# Sto. Niño ES                                4
# Mahayag ES                                  4
# San Carlos ES                               4
# Magallanes ES                               4
# Bagong Silang ES                            4
# Rawis ES                                    4
# Basak ES                                    4
# Sta. Rita ES                                4
# Napo ES                                     4
# Cawayan ES                                  4
# Sta. Isabel ES                              4
# Victoria ES                                 3
# Sto. Cristo ES                              3
# San Nicolas ES                              3
# San Manuel ES                               3
# Macopa ES                                   3
# Lourdes ES                                  3
# Sta. Fe ES                                  3
# Sabang ES                                   3
#                                            ..
# Passi I CS                                  1
# Maatas ES                                   1
# Maraymaray ES                               1
# Gen. Gregorio del Pilar ES                  1
# Lamesa ES                                   1
# San Pero ES                                 1
# Lambug ES                                   1
# Linapew ES                                  1
# Camdilancha ES                              1
# San Bernardo ES                             1
# Palaciawan ES                               1
# Guinsiliban CS                              1
# Juanito G. Alburo ES                        1
# Bantayan ES                                 1
# Don Amadeo Perez Sr. Memorial CS - Main     1
# Don Leon Martinez MES                       1
# Sumilihon CES                               1
# Kawal ES                                    1
# Doña Pepeng ES                              1
# Lapasan ES                                  1
# Palanogan Occ. ES                           1
# Lake Soluton IS                             1
# Abungo PS                                   1
# Ninoy Aquino ES                             1
# Salhag ES                                   1
# Bagumbayan CS                               1
# Datu Mankumbate ES                          1
# Tagpos ES                                   1
# Hda. Enage ES                               1
# Canticum ES                                 1
# Pulo ES                                     1
# Sampig ES                                   1
# Tubigan ES                                  1
# Linglingay ES                               1
# Lambontong ES                               1
# Bayanihan ES                                1
# Paligawan Matanda ES                        1
# Loboc ES                                    1
# Tangub ES                                   1
# Bolos ES                                    1
# Ormocay ES                                  1
# Batug Sur ES                                1
# Cristo Rey East CES                         1
# Tebag ES                                    1
# Tapak ES                                    1
# Sambat ES                                   1
# Ganzano ES                                  1
# Parang ES                                   1
# Surallah East ES                            1
# Luakan ES                                   1
# Name: SchName, Length: 2990, dtype: int64
#
# ---------
# Leyte                        105
# Quezon                        85
# Cebu                          78
# Bohol                         78
# Camarines Sur                 77
# Cagayan                       67
# Zamboanga Del Sur             67
# Samar (Western)               64
# Batangas                      63
# Iloilo                        63
# Bukidnon                      61
# Isabela                       58
# Zamboanga Del Norte           56
# Masbate                       56
# Bulacan                       55
# Palawan                       50
# Nueva Ecija                   49
# North Cotabato                48
# Pangasinan I (Lingayen)       47
# Antique                       47
# Oriental Mindoro              44
# Pampanga                      44
# Negros Oriental               44
# Tarlac                        43
# Negros Occidental             42
# Albay                         42
# Sorsogon                      41
# Pangasinan II (Binalonan)     38
# Eastern Samar                 37
# Northern Samar                37
# Davao Del Sur                 36
# Ilocos Norte                  36
# Misamis Occidental            36
# Davao City                    34
# Surigao Del Sur               34
# Ilocos Sur                    33
# Compostela Valley             33
# Capiz                         32
# Laguna                        32
# La Union                      31
# South Cotabato                31
# Southern Leyte                30
# Zamboanga Sibugay             30
# Misamis Oriental              30
# Benguet                       29
# Camarines Norte               28
# Rizal                         28
# Calbayog City                 25
# Occidental Mindoro            25
# Agusan Del Sur                25
#                             ...
# Tacloban City                  3
# Tangub City                    3
# Surigao City                   3
# Malabon City                   3
# San Jose Del Monte City        3
# Tanauan City                   3
# Meycauayan City                3
# Ligao City                     3
# San Jose City                  3
# Balanga City                   3
# Tabaco City                    2
# Roxas City                     2
# Talisay City                   2
# Marikina City                  2
# Sagay City                     2
# Manila                         2
# Cavite City                    2
# Valenzuela City                2
# Batanes                        2
# Bacoor                         2
# Santiago City                  2
# Naga City                      2
# Muntinlupa City                2
# Bacolod City                   2
# La Carlota City                2
# Tacurong City                  2
# Silay City                     2
# Escalante City                 2
# Taguig / Pateros               2
# Paranaque City                 2
# Tagbilaran City                1
# Digos City                     1
# Tanjay City                    1
# Lamitan                        1
# Valencia City                  1
# Malaybalay City                1
# San Juan City                  1
# Bogo City                      1
# Alaminos City                  1
# Marawi City                    1
# Gapan City                     1
# Munoz Science City             1
# Las Piñas City                 1
# El Salvador City               1
# Cabadbaran City                1
# Tagum City                     1
# Calamba City                   1
# Bais City                      1
# Pasig City                     1
# Laoag City                     1
# Name: DivName, Length: 210, dtype: int64
#
# ---------
# H04    105
# D13     85
# G02     78
# G01     78
# E03     77
# B02     67
# I07     67
# H07     64
# F09     63
# D02     63
# J01     61
# B03     58
# I06     56
# E07     56
# C03     55
# D12     50
# C05     49
# L05     48
# F02     47
# A06     47
# G07     44
# D11     44
# C07     44
# C08     43
# E01     42
# F11     42
# E09     41
# A07     38
# H05     37
# H03     37
# K05     36
# J05     36
# A02     36
# R07     34
# K01     34
# K08     33
# A03     33
# F06     32
# D06     32
# L08     31
# A05     31
# J06     30
# I08     30
# H08     30
# N03     29
# E02     28
# D14     28
# H02     25
# D10     25
# R02     25
#       ...
# E12      3
# C20      3
# M10      3
# K06      3
# C15      3
# R05      3
# D20      3
# C11      3
# M05      3
# M08      2
# E11      2
# B01      2
# M14      2
# E08      2
# M13      2
# M02      2
# L09      2
# F12      2
# D05      2
# B08      2
# F10      2
# F14      2
# F15      2
# F18      2
# M11      2
# F03      2
# G12      2
# M07      2
# D23      2
# G17      1
# G10      1
# G15      1
# G11      1
# C16      1
# J14      1
# M15      1
# K07      1
# M09      1
# K02      1
# P07      1
# J13      1
# J12      1
# D19      1
# A12      1
# A04      1
# R10      1
# P10      1
# A11      1
# C14      1
# M12      1
# Name: DivisionCode, Length: 212, dtype: int64
#
# ---------
# LEYTE                  119
# CEBU                   115
# PANGASINAN             104
# QUEZON                  97
# WESTERN SAMAR           93
# ZAMBOANGA DEL SUR       87
# BATANGAS                84
# CAMARINES SUR           83
# BOHOL                   79
# ILOILO                  77
# NEGROS OCCIDENTAL       76
# ISABELA                 76
# CAGAYAN                 72
# DAVAO DEL SUR           71
# BULACAN                 67
# ZAMBOANGA DEL NORTE     66
# BUKIDNON                63
# MASBATE                 61
# NEGROS ORIENTAL         60
# NUEVA ECIJA             59
# PAMPANGA                57
# PALAWAN                 56
# NORTH COTABATO          52
# MISAMIS OCCIDENTAL      52
# TARLAC                  51
# ALBAY                   51
# ORIENTAL MINDORO        48
# ANTIQUE                 47
# MISAMIS ORIENTAL        47
# SORSOGON                45
# EASTERN SAMAR           43
# ILOCOS NORTE            42
# LAGUNA                  40
# SOUTH COTABATO          40
# SURIGAO DEL SUR         39
# ILOCOS SUR              39
# CAVITE                  37
# SOUTHERN LEYTE          37
# NORTHERN SAMAR          37
# CAPIZ                   34
# BENGUET                 34
# LANAO DEL NORTE         34
# COMPOSTELA VALLEY       33
# AGUSAN DEL SUR          32
# AGUSAN DEL NORTE        32
# LA UNION                32
# LANAO DEL SUR           32
# RIZAL                   32
# ZAMBOANGA SIBUGAY       30
# CAMARINES NORTE         28
# DAVAO DEL NORTE         28
# KALINGA                 26
# MAGUINDANAO             26
# SURIGAO DEL NORTE       26
# OCCIDENTAL MINDORO      25
# NUEVA VIZCAYA           23
# AKLAN                   22
# SULTAN KUDARAT          22
# DAVAO ORIENTAL          22
# IFUGAO                  21
# SULU                    21
# BATAAN                  20
# ZAMBALES                19
# MARINDUQUE              19
# CATANDUANES             19
# BILIRAN                 18
# ROMBLON                 18
# MOUNTAIN PROVINCE       17
# NCR - 3RD DISTRICT      16
# ABRA                    14
# NCR -2ND DISTRICT       14
# DINAGAT ISLANDS         14
# AURORA                  13
# BASILAN                 12
# GUIMARAS                11
# APAYAO                  11
# NCR -4TH DISTRICT       10
# QUIRINO                 10
# SARANGANI                8
# TAWI-TAWI                7
# CITY OF ISABELA          6
# CAMIGUIN                 5
# SIQUIJOR                 4
# CITY OF COTABATO         4
# NCR - 1ST DISTRICT       2
# BATANES                  2
# Name: Province, dtype: int64
#
# ---------
# DAVAO CITY                       34
# CALBAYOG CITY                    25
# SAN FERNANDO                     20
# SAN JOSE                         16
# PILAR                            16
# QUEZON                           15
# SAN CARLOS CITY                  15
# BUENAVISTA                       15
# BUTUAN CITY (Capital)            15
# SANTA CRUZ                       14
# SAN ISIDRO                       14
# ZAMBOANGA CITY                   13
# SAN MIGUEL                       13
# DOLORES                          13
# CONCEPCION                       12
# CARMEN                           12
# NAUJAN                           11
# CITY OF TABUK (Capital)          11
# ILAGAN (Capital)                 10
# SINDANGAN                        10
# MAGSAYSAY                        10
# ILIGAN CITY                      10
# ROSARIO                          10
# QUEZON CITY                      10
# CLAVERIA                         10
# LIPA CITY                        10
# SIBALOM                          10
# SANTA MARIA                      10
# BINANGONAN                        9
# BAGGAO                            9
# SAN MATEO                         9
# JOSE ABAD SANTOS (TRINIDAD)       8
# ALICIA                            8
# BASEY                             8
# SAN REMIGIO                       8
# SANTO TOMAS                       8
# SANTO DOMINGO                     8
# OROQUIETA CITY (Capital)          8
# CAGAYAN DE ORO CITY (Capital)     8
# SAN ILDEFONSO                     8
# HILONGOS                          8
# SAN LUIS                          8
# ESPERANZA                         8
# CITY OF TARLAC (Capital)          8
# BATANGAS CITY (Capital)           8
# RIZAL                             8
# CITY OF URDANETA                  8
# GINGOOG CITY                      8
# DARAGA (LOCSIN)                   7
# CITY OF PASSI                     7
#                                  ..
# CAGAYANCILLO                      1
# CASTILLEJOS                       1
# BANSALAN                          1
# SOGOD                             1
# SINACABAN                         1
# IGUIG                             1
# TRINIDAD                          1
# DANAO                             1
# MAIGO                             1
# TALUGTUG                          1
# DITSAAN-RAMAIN                    1
# MAPANAS                           1
# SAN LORENZO RUIZ (IMELDA)         1
# DILASAG                           1
# PANDAMI                           1
# PRESIDENT QUIRINO                 1
# LAGONOY                           1
# PAGAYAWAN (TATARIKAN)             1
# PATNANUNGAN                       1
# PROSPERIDAD (Capital)             1
# MUTIA                             1
# CUYO                              1
# BACUNGAN (LEON T. POSTIGO)        1
# CITY OF TANJAY                    1
# GITAGUM                           1
# TARRAGONA                         1
# LAVEZARES                         1
# TANGALAN                          1
# APALIT                            1
# PAGALUNGAN                        1
# ANGONO                            1
# PATEROS                           1
# GANASSI                           1
# CARMONA                           1
# CITY OF ALAMINOS                  1
# BARBAZA                           1
# CORELLA                           1
# CARDONA                           1
# SAPA-SAPA                         1
# SANTA MAGDALENA                   1
# ARACELI                           1
# BOCAUE                            1
# BANGUI                            1
# MAHAPLAG                          1
# TALAINGOD                         1
# BAIS CITY                         1
# MAGALLANES                        1
# ALILEM                            1
# BANATE                            1
# CITY OF DIGOS (Capital)           1
# Name: MunicipalityORCity, Length: 1160, dtype: int64
#
# ---------
# VIII      347
# IV-A      290
# V         287
# III       286
# VI        267
# VII       258
# I         217
# X         201
# IX        189
# II        183
# IV-B      166
# XI        154
# CARAGA    143
# XII       126
# CAR       123
# ARMM       98
# NCR        42
# Name: Region, dtype: int64
#
# ---------
# School with no Annexes          3310
# Mother school                     42
# Annex or Extension school(s)      24
# Mobile School(s)/Center(s)         1
# Name: SchoolType, dtype: int64
#
# ---------

# %% [markdown]
# ### Numerical Data

# %%
#Unexpected outliers or anomalous values (NUM)
#Inconsistent or incorrect units of measurement (NUM)

# %%
#Check the Number of Numerical Features
DF_num.shape
# Out:
# (3377, 21)

# %%
#Describe the Numerical Features. Check if the Mean, Min, and Max values are as expected.
DF_num.describe()
# Out:
#           SchID  Clusters  Filipino  AralinP  Mathematics  Science  English  \
# count   3377.00   3377.00   3377.00  3377.00      3377.00  3377.00  3377.00
# mean  121042.84      4.89     71.92    74.10        76.91    71.67    76.67
# std    20254.52      1.08     11.82    16.10        17.70    16.77    15.32
# min   100003.00      1.00     27.00    16.84        16.61    21.29    24.00
# 25%   109134.00      4.00     64.37    65.00        67.32    61.02    68.89
# 50%   118739.00      5.00     73.28    77.71        81.60    74.62    80.38
# 75%   127712.00      6.00     81.06    86.39        90.49    84.84    88.12
# max   500019.00      6.00     97.50    99.83       100.00   100.00   100.00
#
#        Overall  Internet     Lat    Long  Enrolled  Teachers   Ratio  \
# count  3377.00   3377.00 3377.00 3377.00   3377.00   3377.00 3377.00
# mean     74.25      0.41   11.92  122.87    508.84     14.55   31.98
# std      14.01      0.49    3.46    1.83   1308.85     35.39   10.28
# min      26.00      0.00    4.79  117.09     11.00      1.00    2.00
# 25%      66.38      0.00    8.95  121.15    154.00      6.00   25.00
# 50%      77.36      0.00   11.68  122.98    255.00      8.00   32.00
# 75%      84.95      1.00   14.66  124.47    489.00     14.00   38.00
# max      97.50      1.00   60.70  126.57  58709.00   1630.00  177.00
#
#        Energized    Grid     PBOR  PovertyCluster  PovertyIncidence  \
# count    3377.00 3377.00  3377.00         3377.00           3377.00
# mean        0.91    0.86  5889.64            3.03             21.68
# std         0.28    0.34  5666.44            1.24             12.92
# min         0.00    0.00   277.29            1.00              0.00
# 25%         1.00    1.00   277.29            2.00             12.00
# 50%         1.00    1.00  8982.00            3.00             19.00
# 75%         1.00    1.00 10732.00            4.00             30.00
# max         1.00    1.00 15781.00            5.00             66.00
#
#        LowerLimit  UpperLimit
# count     3377.00     3377.00
# mean        15.55       27.10
# std         10.65       16.04
# min          0.00        0.00
# 25%          8.00       16.00
# 50%         14.00       25.00
# 75%         21.00       39.00
# max         61.00       72.00

# %% [markdown]
# ## Find Patterns, Spot Anomalies, Test Hypothesis using Descriptive Statistics

# %% [markdown]
# ### Univariate Plots to Check Variable Characteristics

# %% [markdown]
# #### Histograms

# %%
# All features can be plotted on a histogram
DF.Overall.hist()

# %%
sns.countplot(DF['Internet'])

# %%
sns.countplot(DF['Energized'])

# %% [markdown]
# #### Density Plot

# %%
sns.distplot(DF['Overall'])

# %%
sns.distplot(DF['Ratio'])

# %% [markdown]
# #### What can you obseve about the target variable Overall?
# * How is it distributed
# * In terms of skewness?
# * Are there outliers?

# %%
#Quantify Skewness and Kurtosis
print("Skewness: %f" % DF['Overall'].skew())
print("Kurtosis: %f" % DF['Overall'].kurt())
# Out:
# Skewness: -0.914092
# Kurtosis: 0.285742

# %% [markdown]
# * Skewness is a measure of symmetry, or more precisely, the lack of symmetry. A distribution, or data set, is symmetric if it looks the same to the left and right of the center point.
#     * Normal Distribution: = 0
#     * Skewed Right: +
#     * Skewed Left: -
# <br><br>
# * Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers. Data sets with low kurtosis tend to have light tails, or lack of outliers
#     * Normal Distribution: = 0
#     * Heavy Tailed: +
#     * Light Tailed: -
#
# <a href="https://www.itl.nist.gov/div898/handbook/eda/section3/eda35b.htm">Further Information</a>

# %% [markdown]
# #### Box Plot
# <a href="https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots">Interpreting Box Plots </a>

# %%
sns.boxplot(DF.Overall, orient='v')

# %%
col = 'Region'
data = pd.concat([DF['Overall'], DF[col]], axis=1)

f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=col, y="Overall", data=data)
fig.axis(ymin=0, ymax=100);
plt.xticks(rotation=90);

# %% [markdown]
# ### Create bins and drop unnecessary columns

# %%
DF[['Math', 'Fil', 'AP', 'Sci', 'Eng']] = DF[[ 'Mathematics', 'Filipino', 'AralinP', 'Science', 'English']].astype(int)

# %%
DF['Div'] = DF['DivName'].astype('category')

# %%
bins = [0, 65, 100]
DF['Average'] = np.searchsorted(bins, DF['Overall'].values)

# %%
df = DF.drop(['SchID', 'SchName', 'DivName', 'Clusters', 'DivisionCode','Lat', 'Long', 'Enrolled', 'Teachers'], axis=1)

# %%
df.columns
# Out:
# Index([u'Province', u'MunicipalityORCity', u'Region', u'Filipino', u'AralinP',
#        u'Mathematics', u'Science', u'English', u'Overall', u'Internet',
#        u'Ratio', u'Energized', u'Grid', u'SchoolType', u'PBOR',
#        u'PovertyCluster', u'PovertyIncidence', u'LowerLimit', u'UpperLimit',
#        u'Math', u'Fil', u'AP', u'Sci', u'Eng', u'Div', u'Average'],
#       dtype='object')

# %%
df[['Region', 'SchoolType']].apply(lambda x: x.astype('category'))
# Out:
#       Region              SchoolType
# 0        CAR  School with no Annexes
# 1        CAR  School with no Annexes
# 2        CAR  School with no Annexes
# 3        CAR  School with no Annexes
# 4        CAR  School with no Annexes
# 5        CAR  School with no Annexes
# 6        CAR  School with no Annexes
# 7        CAR  School with no Annexes
# 8        CAR  School with no Annexes
# 9        CAR  School with no Annexes
# 10       CAR  School with no Annexes
# 11       CAR  School with no Annexes
# 12       CAR  School with no Annexes
# 13       CAR  School with no Annexes
# 14    CARAGA  School with no Annexes
# 15    CARAGA  School with no Annexes
# 16    CARAGA  School with no Annexes
# 17    CARAGA  School with no Annexes
# 18    CARAGA  School with no Annexes
# 19    CARAGA  School with no Annexes
# 20    CARAGA           Mother school
# 21    CARAGA  School with no Annexes
# 22    CARAGA  School with no Annexes
# 23    CARAGA  School with no Annexes
# 24    CARAGA  School with no Annexes
# 25    CARAGA  School with no Annexes
# 26    CARAGA  School with no Annexes
# 27    CARAGA  School with no Annexes
# 28    CARAGA  School with no Annexes
# 29    CARAGA  School with no Annexes
# 30    CARAGA  School with no Annexes
# 31    CARAGA  School with no Annexes
# 32    CARAGA  School with no Annexes
# 33    CARAGA  School with no Annexes
# 34    CARAGA  School with no Annexes
# 35    CARAGA  School with no Annexes
# 36    CARAGA  School with no Annexes
# 37    CARAGA  School with no Annexes
# 38    CARAGA  School with no Annexes
# 39    CARAGA  School with no Annexes
# 40    CARAGA  School with no Annexes
# 41    CARAGA  School with no Annexes
# 42    CARAGA  School with no Annexes
# 43    CARAGA  School with no Annexes
# 44    CARAGA  School with no Annexes
# 45    CARAGA  School with no Annexes
# 46    CARAGA  School with no Annexes
# 47    CARAGA  School with no Annexes
# 48    CARAGA  School with no Annexes
# 49    CARAGA  School with no Annexes
# ...      ...                     ...
# 3327      IX  School with no Annexes
# 3328      IX  School with no Annexes
# 3329      IX  School with no Annexes
# 3330      IX  School with no Annexes
# 3331      IX  School with no Annexes
# 3332      IX  School with no Annexes
# 3333      IX  School with no Annexes
# 3334      IX  School with no Annexes
# 3335      IX  School with no Annexes
# 3336      IX  School with no Annexes
# 3337      IX  School with no Annexes
# 3338      IX  School with no Annexes
# 3339      IX  School with no Annexes
# 3340      IX  School with no Annexes
# 3341      IX  School with no Annexes
# 3342      IX  School with no Annexes
# 3343      IX  School with no Annexes
# 3344      IX  School with no Annexes
# 3345      IX  School with no Annexes
# 3346      IX  School with no Annexes
# 3347      IX  School with no Annexes
# 3348      IX  School with no Annexes
# 3349      IX  School with no Annexes
# 3350      IX  School with no Annexes
# 3351      IX  School with no Annexes
# 3352      IX  School with no Annexes
# 3353      IX  School with no Annexes
# 3354      IX  School with no Annexes
# 3355      IX  School with no Annexes
# 3356      IX  School with no Annexes
# 3357      IX  School with no Annexes
# 3358      IX  School with no Annexes
# 3359      IX  School with no Annexes
# 3360      IX  School with no Annexes
# 3361      IX  School with no Annexes
# 3362      IX  School with no Annexes
# 3363      IX  School with no Annexes
# 3364      IX  School with no Annexes
# 3365      IX  School with no Annexes
# 3366      IX  School with no Annexes
# 3367      IX  School with no Annexes
# 3368      IX  School with no Annexes
# 3369      IX  School with no Annexes
# 3370      IX  School with no Annexes
# 3371      IX  School with no Annexes
# 3372      IX  School with no Annexes
# 3373      IX  School with no Annexes
# 3374      IX  School with no Annexes
# 3375      IX  School with no Annexes
# 3376      IX  School with no Annexes
#
# [3377 rows x 2 columns]

# %%
df.Region = pd.Categorical(df.Region)
df['Reg'] = df.Region.cat.codes

# %%
df.SchoolType = pd.Categorical(df.SchoolType)
df['SType'] = df.SchoolType.cat.codes

# %%
df.Div = pd.Categorical(df.Div)
df['DName'] = df.Div.cat.codes

# %%
df2 = df.drop(['Grid', 'DName', 'MunicipalityORCity', 'Province', 'PovertyCluster', 'LowerLimit', 'UpperLimit', 'Mathematics', 'Science', 'English', 'Filipino', 'AralinP', 'Region', 'SchoolType', 'Div', 'Math', 'Fil', 'AP', 'Sci', 'Eng', 'Overall'], axis=1)

# %%
df2.head()
# Out:
#    Internet  Ratio  Energized     PBOR  PovertyIncidence  Average  Reg  SType
# 0         0     23          1 15781.00                20        1    1      3
# 1         1     37          1 15781.00                20        2    1      3
# 2         0     32          1 15781.00                20        2    1      3
# 3         0     20          1 15781.00                20        2    1      3
# 4         1     19          1 15781.00                20        2    1      3

# %% [markdown]
# ### Multivariate Plots to Understand Relatonships between Features, Test Hypothesis and Check Assumptions

# %% [markdown]
# #### Correlation Matrix

# %%
corrmat = df2.corr()

# %%
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True, cmap="YlOrRd");

# %% [markdown]
# <i> Take note of multi-colinearity! </i>

# %%
#View the Correlation Matrix
corrmat
# Out:
#                   Internet  Ratio  Energized  PBOR  PovertyIncidence  Average  \
# Internet              1.00   0.13       0.18  0.04             -0.21    -0.02
# Ratio                 0.13   1.00       0.00 -0.08             -0.06    -0.13
# Energized             0.18   0.00       1.00  0.12             -0.19     0.13
# PBOR                  0.04  -0.08       0.12  1.00             -0.26     0.05
# PovertyIncidence     -0.21  -0.06      -0.19 -0.26              1.00    -0.01
# Average              -0.02  -0.13       0.13  0.05             -0.01     1.00
# Reg                  -0.06  -0.02      -0.03 -0.03              0.25     0.13
# SType                 0.01   0.05       0.02  0.00              0.04     0.00
#
#                    Reg  SType
# Internet         -0.06   0.01
# Ratio            -0.02   0.05
# Energized        -0.03   0.02
# PBOR             -0.03   0.00
# PovertyIncidence  0.25   0.04
# Average           0.13   0.00
# Reg               1.00   0.04
# SType             0.04   1.00

# %% [markdown]
# Check features with the highest correlation with target

# %%
# Feature sorted by correlation to Overall, from positive to negative
corr = corrmat.sort_values('Average', ascending=False)
plt.figure(figsize=(8,10))
sns.barplot( corr.Average[1:], corr.index[1:], orient='h')
plt.show()

# %%
#Correlation with output variable
cor_target = abs(corrmat["Average"])

#Selecting highly correlated features (Anything with a correlation >0.5)
relevant_features = cor_target[cor_target>0.01]
relevant_features.sort_values(ascending=False)
# Out:
# Average     1.00
# Ratio       0.13
# Reg         0.13
# Energized   0.13
# PBOR        0.05
# Internet    0.02
# Name: Average, dtype: float64

# %% [markdown]
# Zoom in on highest correlated features

# %%
#Saleprice correlation matrix

#number of variables for heatmap
k = 10 

cols = corrmat.nlargest(k, 'Average')['Average'].index

cm = abs(np.corrcoef(df2[cols].values.T))

sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cmap = 'YlOrRd', cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)

plt.show()

# %% [markdown]
# Form & test hypothesis -  *which variables contribute to Math score?*

# %% [markdown]
# #### Scatterplots

# %%
#Select Features to Plot Against Overall (Target)
cols = ['Ratio', 'Internet', 'Energized', 'Reg', 'PovertyIncidence', 'SType', 'PBOR']

# %%
f = pd.melt(df2, id_vars=['Average'], value_vars=sorted(cols))

# %%
f.head()
# Out:
#    Average   variable  value
# 0        1  Energized   1.00
# 1        2  Energized   1.00
# 2        2  Energized   1.00
# 3        2  Energized   1.00
# 4        2  Energized   1.00

# %%
g = sns.FacetGrid(f, col='variable', col_wrap=4, sharex=False, sharey=False)
plt.xticks(rotation='vertical')

g = g.map(sns.regplot, 'value', 'Average', scatter_kws={'alpha':0.3})
[plt.setp(ax.get_xticklabels(), rotation=60) for ax in g.axes.flat]
g.fig.tight_layout()
plt.show()

# %%
#scatter plot internet/overall
sns.regplot(x = 'Internet', y = 'Average', data = df2)

# %% [markdown]
# *There appears to be a linear relationship between Living Area and Sale Price*

# %%
sns.regplot(x = 'Energized', y = 'Average', data = df2)

# %% [markdown]
# #### Violin Plots
# <a href = "https://datavizcatalogue.com/methods/violin_plot.html">Interpreting Violin Plots</a>

# %%
# Violinplots on SalePrice given Functional feature, categorical data
sns.violinplot(data=df2,x="Energized", y="Average")

# %%
# Violinplots on SalePrice given Functional feature, categorical data
sns.violinplot(data=df2,x="Internet", y="Average")

# %% [markdown]
# #### Pair Plots
# <i>If you want all plots in one go</i>

# %%
sns.set()
cols = ['Ratio', 'Internet', 'Energized', 'Reg', 'PovertyIncidence', 'SType', 'PBOR']
sns.pairplot(df[cols], size = 2.5)
plt.show();

# %% [markdown]
# _________
